# %%
# !pip3 install backgroundremover

# %%
import gradio as gr
from serpapi import GoogleSearch

def display_products(query):
    """
    Display products based on the given query.

    Args:
        query (str): The search query for the products.

    Returns:
        str: HTML string containing the display of products with their thumbnails, titles, prices, stores, and links.
    """
    params = {
        "engine": "google_shopping",
        "q": query,
        "location": "Bengaluru, Karnataka, India",
        "google_domain": "google.com",
        "gl": "in",
        "hl": "en",
        "api_key": "9023d4dbcce2c3e065d7983a642218de01ad8c1cc6a9f556d6dd6bd7351943af"
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    shopping_results = results["shopping_results"]
    shopping_results= shopping_results[:min(15, len(shopping_results))]

    ListOfThumbnails = [items.get('thumbnail') for items in shopping_results]
    ListOfTitles = [items.get('title') for items in shopping_results]
    ListOfPrices = [items.get('price') for items in shopping_results]
    ListOfLinks = [items.get('link') for items in shopping_results]
    ListOfStores = [items.get('source') for items in shopping_results]

    product_display = ""
    for i in range(len(ListOfThumbnails)):
        product_display += f"<img src='{ListOfThumbnails[i]}' width=200><br>"
        product_display += f"<b>Title:</b> {ListOfTitles[i]}<br>"
        product_display += f"<b>Price:</b> {ListOfPrices[i]}<br>"
        product_display += f"<b>Store:</b> {ListOfStores[i]}<br>"
        product_display += f"<a href='{ListOfLinks[i]}' target='_blank'>Link</a><br><br>"

    return product_display

gr.Interface(
    fn=display_products,
    inputs="text",
    outputs="html",
    title="Google Shopping Search",
    description="Enter the product you want to search for",
    allow_flagging=False,
    theme="huggingface",
).launch()
# Out:
# /home/alpha/.local/lib/python3.10/site-packages/gradio/blocks.py:736: UserWarning: Cannot load huggingface. Caught Exception: 404 Client Error: Not Found for url: https://huggingface.co/api/spaces/huggingface (Request ID: Root=1-6635551c-62d8d7bb37dd8dba1df8dcdd;7a442772-81e8-4c4c-8e5f-667dd1607ffa)
#
# Sorry, we can't find the page you are looking for.
#   warnings.warn(f"Cannot load {theme}. Caught Exception: {str(e)}")
# /home/alpha/.local/lib/python3.10/site-packages/gradio/interface.py:377: UserWarning: The `allow_flagging` parameter in `Interface` nowtakes a string value ('auto', 'manual', or 'never'), not a boolean. Setting parameter to: 'never'.
#   warnings.warn(
# Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_lens",
  "url": "https://m.media-amazon.com/images/I/616fNtdi9WL.jpg",
  "api_key": "9023d4dbcce2c3e065d7983a642218de01ad8c1cc6a9f556d6dd6bd7351943af"
}

search = GoogleSearch(params)
results = search.get_dict()
visual_matches = results["visual_matches"]

# %%
visual_matches
# Out:
# [{'position': 1,
#   'title': "Buy ASIAN Men's Tarzan-11 White Casual Sneaker High-Neck Shoes with Lightweight Extra Cushion Lace-Up Shoes for Men's & Boy's at Amazon.in",
#   'link': 'https://www.amazon.in/ASIAN-Tarzan-11-Sneaker-High-Neck-Lightweight/dp/B0CD4FXNXT',
#   'source': 'Amazon.in',
#   'source_icon': 'https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn:ANd9GcR2emfet7RmzmPRsHjYm_UPCTAgzmbvxRasG6I2u0I4LbQ54ZknecWGFOlBWs77JqzWT4yV05Z70DroaUwrYGlJKA1RUCO8YFzPxNBQf8kSXLfu',
#   'thumbnail': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9Gc

#   'thumbnail': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSa_LhUSJHIKJWK3iu7DsFD9VNJIeBdtJyVv-QxxUb21XK0a01q'},
#  {'position': 33,
#   'title': 'Nike SB Dunk Low Ben Jerrys Chunky Dunky 15 for Sale in Bell Gardens, CA - OfferUp',
#   'link': 'https://offerup.com/item/detail/e67a3bbc-16cc-319a-9be3-2e84041d2490',
#   'source': 'OfferUp',
#   'source_icon': 'https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn:ANd9GcQOpn8VGWE4WTPZ8ydi0mIUqrcXCa_ZGdiYvmSvv1ZTfocziUicxQd6cA902k4n4Iltki0oLHp-19WnwtXmnl0VkrXpSxjkv8AOsbdoHE_4yg',
#   'price': {'value': '$192.00*', 'extracted_value': 192.0, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRG7EXRy6BKVxQmcWbdRc1NNJ2ILi3MmFjUVKO1QhCGTWh2RL0O',
#   'condition': 'Used'},
#  {'position': 34,
#   'title': 'Kids Color Block Lace up Sneakers - 4-5 Years,Blue',
#   'link': 'https://tinyjumps.com/product/basketsnkr/',
#   'source': 'TinyJumps',
#   'source_icon': 'https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcQJ2wesytKCWiwPPYg0Ki91esoZ5WLrDpydE4vr11CeHDAHz4uS2iSAYAjbAskHSnbX-cKzVKxR5T8JcraD0RspFVWwpCsL4800dYgNpgLzfjpG',
#   'price': {'value': '$37.90*', 'extracted_value': 37.9, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTbcy4JSIRYAfPPLRWut2JPwdRlACZKLbe6r8W1U9zWLDB7_zvB',
#   'in_stock': True},
#  {'position': 35,
#   'title': "Cheap Minority Skateboard Shoes Casual Sports Student Men's Sneakers Street Style Walking Shoes For Men Punk Basketball Sport Sneakers | Joom",
#   'link': 'https://www.joom.com/en/products/64d35f923f3efe010cb6cf87',
#   'source': 'joom.com',
#   'source_icon': 'https://encrypted-tbn2.gstatic.com/favicon-tbn?q=tbn:ANd9GcTZbm0hOgNcRLF_TnhOdpND_HPKJ8qc7ILtS6nQJzqofEbYaliCg3oncGw6oZk8_JJUHSh8UJZQGhX1teBnL0ql2wafJoNmXwuMmzipeiuz0XE',
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSM5VMMdb8eMz8hq0riGa4kcFLeaurGwlvrSeRnUHH2D3Q7LT1q'},
#  {'position': 36,
#   'title': "Nike Men's Multi Trainers",
#   'link': 'https://www.depop.com/products/smkaho-nike-air-trainer-sc-high-5fe9/',
#   'source': 'Depop',
#   'source_icon': 'https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn:ANd9GcSZEid_PL6y2TyvsM_Eo2MdfBQ4Byd5_y_7a_j5ApTdJp91TLa0l86JfvQIbE1_UXqftg4hfKishOHlAMVoodnuCkh51jpczyLlhFdHAC7iXw8H',
#   'rating': 4.7,
#   'reviews': 497,
#   'price': {'value': '$55.00*', 'extracted_value': 55.0, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTak-zF6TFB1Yi-lxOEXP0S7Hy6uzzl9-vMGM2r4N_sr4sdk1li',
#   'condition': 'Used'},
#  {'position': 37,
#   'title': 'Reebok Shaq Attaq x Street Fighter Core Black/Dark Sable/Luxe Blue Men Size 11',
#   'link': 'https://www.ebay.com.my/itm/144984799540',
#   'source': 'eBay',
#   'source_icon': 'https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn:ANd9GcTJ2jV7jNGHlQepIax-mL_oMAdhV1hbmmRIhNj1Yg3ZVUoAG5VboA48ZJ4gcwVXSk3D9ug9suTpZsU44I9MCZy3hdnRwhNw06FpYTez9qSVnqXRoBo',
#   'rating': 4.5,
#   'reviews': 84,
#   'price': {'value': '$99.98*', 'extracted_value': 99.98, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRUqUmBZ8l8YDzqJADZQYhuNwjp39iYBOOZu873ri7Wk65e5b1B',
#   'in_stock': True},
#  {'position': 38,
#   'title': 'Saint Rowan Multi Leather Sneakers – SaintG UK',
#   'link': 'https://saintg.uk/products/saint-nicol-multi-leather-sneakers',
#   'source': 'SaintG UK',
#   'source_icon': 'https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcT_y1QBvlvn_PQBe0V9xE5Abfex4n0oNUXct6PkNOB5rp_vZycqjlrAoUeuIQj1A13ppud3MAmICuRjFkVtDlrI9kAriKjeRFh3nXAcK00',
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1cEE1JvIeCtS_h9clCzqsWhbIXU6pFk8k__FW-dJwg09aDeQn'},
#  {'position': 39,
#   'title': "BAPE STA 88 #1, Men's Fashion, Footwear, Sneakers on Carousell",
#   'link': 'https://us.carousell.com/p/bape-sta-88-1-1287053245/',
#   'source': 'Carousell',
#   'source_icon': 'https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn:ANd9GcT4Ti5-YOpBfbiMqE7p7RZfKm7O3samC81f3dy47m26F83oKMX9_LfdIxbyDR0KosdhB0Bxduy-VwL2q9Az47dyR_YpTfzU-QrCtkdkaAz6ayw6Y2FS',
#   'thumbnail': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQLN24z1Me6WkAJYJhzgsaBn37BmAY_wIXUTOWevdKY8oTrhzvt'},
#  {'position': 40,
#   'title': "Men's White Lax Mid-top Trainers",
#   'link': 'https://www.lyst.co.uk/shoes/saint-laurent-lax-mid-top-sneakers-1/',
#   'source': 'Lyst UK',
#   'source_icon': 'https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn:ANd9GcTXB-qax9dMcusppHQwO_umNPwZGb9xxQwrLaOaSuax12ic9sAPxdaqkNCsEHpkYpM9mhPB7xBb-ajm0t4VuxynJs9-Dd3W8g26Tsoyk_D6JZpgmA',
#   'price': {'value': '£850.00*', 'extracted_value': 850.0, 'currency': '£'},
#   'thumbnail': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTUi3UxDZe1VzC_q4X994tjZHgTiBz8Z946yVRHzRBJUl7HOdHD',
#   'in_stock': True},
#  {'position': 41,
#   'title': 'smokeahontas😮\u200d💨 (@pierced_cooch) / X',
#   'link': 'https://twitter.com/pierced_cooch',
#   'source': 'X',
#   'source_icon': 'https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn:ANd9GcTobhbt0ZKwS5VFQSzydvQt8vjhhiwervtw9rdJdbWu12RMXaoRjkTltT0aoTWQ6_jjnhnlkM8mMaX4wNSw065V_4Iu62Ljd402sY56ddVX_w',
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTo-6MMGkSdMtTlY7uoTshrnkywJrSegIHIiYAjsNxBIdWwXuIv'},
#  {'position': 42,
#   'title': "JUSTSL 2023 spring Soft soled Children's sneakers boy girl High cut basketball kids shoes size 21-32 | Lazada PH",
#   'link': 'https://www.lazada.com.ph/products/justsl-2023-spring-soft-soled-childrens-sneakers-boy-girl-high-cut-basketball-kids-shoes-size-21-32-i3564088866.html',
#   'source': 'Lazada Philippines',
#   'source_icon': 'https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn:ANd9GcSwPZfZzDpxbs5FlxUleo3gV5smnXUwHmN9wdLIXeoSaJUW4ZP-kY3tXHZS1cTyw-rAbjqe5mQJnxPGrkCFmYuEppTD1zcAhPSzMoPVHjYn2rhv_isWmA',
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTBawbqOj1lRQtWL8jAfofn38YD7fZ1LCX39QwvD861x3z6wdmn'},
#  {'position': 43,
#   'title': 'Nike Air Jordan Legacy 312 (GS)(W) CI4446-400',
#   'link': 'https://www.carousell.com.my/p/nike-air-jordan-legacy-312-gs-w-ci4446-400-1045149190/',
#   'source': 'Carousell Malaysia',
#   'source_icon': 'https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn:ANd9GcQSIwzQva0CiW118fxPnE-X3LUYu3hemXJTQQ5g8CxbQtyzju_p9iIhyK4bB3zYdn96_r2qg6ZA7vreuYfSBpUxrDewvF3d0WJzO4ntOSkZwTiIoAivwfOvzw',
#   'price': {'value': 'MYR\xa0999.00*',
#    'extracted_value': 999.0,
#    'currency': 'M'},
#   'thumbnail': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRUnmTyC0ruWW2gNXSR_xnuculoxL2IZMG_YKoiDD347BpJFMKB',
#   'in_stock': False},
#  {'position': 44,
#   'title': "Nike SB Dunk Low Ben & Jerry's Chunky Dunky (FF Packaging) | Vinted",
#   'link': 'https://www.vinted.co.uk/items/2271614207-nike-sb-dunk-low-ben-jerry-s-chunky-dunky-ff-packaging',
#   'source': 'Vinted UK',
#   'source_icon': 'https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn:ANd9GcSwhFLIGHllVQDwUDUOb4A9tFz5c0JHnphvIgljADc6uR1dS-JscMUFvYhSWWl2j-JxNXww3oBbVfPjJVeWyWzP-6UU7tty2b4ik51w3Zhba9QfNpxR',
#   'thumbnail': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcS2DoehyBZPCUgJl_ouWfvjjsEKL_JSSa3beHtVuaw_1XCAdvMj'},
#  {'position': 45,
#   'title': 'CA PRO SUM POP PUMA – OLIMPIADI CORATO',
#   'link': 'https://olimpiadicorato.it/products/ca-pro-sum-pop-puma',
#   'source': 'Olimpiadi Corato',
#   'source_icon': 'https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcSaPcb-hCCo68bICp-wIJPuX0G66MSrOfabh11alA0vNvNxg4kLbwaPhm8TVF0mTAV2TJiyiQGEbER-BKyoYji11owPOhEu40B0jKy3cPU7FJ5lQeI4KVQ',
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTh3pBKS2D5wHFwi8Lhbihy40yeIWuX9tEPcdGRwrKXEGjE_EUb'},
#  {'position': 46,
#   'title': 'asian Casual Sneaker Shoes For Men | Enhanced Comfort with Cushioned Insole High Tops For Men',
#   'link': 'https://www.flipkart.com/asian-casual-sneaker-shoes-men-enhanced-comfort-cushioned-insole-high-tops/product-reviews/itm3c07887b1037f?pid=SHOGRZMD57GUYPYQ&lid=LSTSHOGRZMD57GUYPYQNLWKZL&mid=FLIPKART&cat=MensSportsFootwear&vert=SpHighTops',
#   'source': 'Flipkart',
#   'source_icon': 'https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcTZINa-Te7bv8MscB5b6FfK__Uu4XBkWQsis7wRqrWRsMISW0ldAmte6VNWHgquxAHZyLYCZZswiMTaqLML3WB19-_CfgDoKZ-dupPqPfoV6TgbXdaR',
#   'price': {'value': '₹857.00*', 'extracted_value': 857.0, 'currency': '₹'},
#   'thumbnail': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRQn25TJCerZJpRPxBvs6ukzaASKsNg0YGc15vKniN-2SG7eF8j',
#   'in_stock': True},
#  {'position': 47,
#   'title': 'asian Casual Sneaker Shoes For Men | Enhanced Comfort with Cushioned Insole High Tops For Men',
#   'link': 'https://www.flipkart.com/asian-casual-sneaker-shoes-men-enhanced-comfort-cushioned-insole-high-tops/p/itm3c07887b1037f?pid=SHOGRZMDXYMSJUCP&lid=LSTSHOGRZMDXYMSJUCPSQADZI&marketplace=FLIPKART',
#   'source': 'Flipkart',
#   'source_icon': 'https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcTZINa-Te7bv8MscB5b6FfK__Uu4XBkWQsis7wRqrWRsMISW0ldAmte6VNWHgquxAHZyLYCZZswiMTaqLML3WB19-_CfgDoKZ-dupPqPfoV6TgbXdaR',
#   'price': {'value': '₹790.00*', 'extracted_value': 790.0, 'currency': '₹'},
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQaG_SKnkilk3aaYAKIBI3Lj4nJDSJ6SvoRSA16oEtpnkVVrWO_',
#   'in_stock': True},
#  {'position': 48,
#   'title': "Buy ASIAN Boy's Tarzan-11 Kids Casual White Sneaker with Hi-Neck Lightweight Synthetic Upper Lace-Up Shoes for Kid's & Boy's at Amazon.in",
#   'link': 'https://www.amazon.in/ASIAN-Tarzan-11-Sneaker-Lightweight-Synthetic/dp/B0CNNBB822',
#   'source': 'Amazon.in',
#   'source_icon': 'https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn:ANd9GcR2emfet7RmzmPRsHjYm_UPCTAgzmbvxRasG6I2u0I4LbQ54ZknecWGFOlBWs77JqzWT4yV05Z70DroaUwrYGlJKA1RUCO8YFzPxNBQf8kSXLfu',
#   'thumbnail': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRYWviTmOKez8Khitd8rZ6FObljDMVaYgUDcsyjDpqZCcxJtgIF'},
#  {'position': 49,
#   'title': 'Asian DESIRE Running Sports Shoe For Men – Asian Footwears',
#   'link': 'https://www.asianfootwears.com/products/asian-desire-running-sports-shoe-for-men',
#   'source': 'Asian Footwears',
#   'source_icon': 'https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcTz3GkZ5pgF1jw7noO7FU-oSrHZ1p_QM9WeRa4I0LhtRLJFtKX1lrel0HYDr2JwPtsuoQmXrvejDhzJkhaqqw1b_hVQHFaWQiUux1-lRgFVSMwLYIafYT7Vee2o',
#   'thumbnail': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcT9yemFm8iNXXqtZRhePFKa3qFnD3aftxy0KEVLpN_hI0GZ-s-f'},
#  {'position': 50,
#   'title': '2023 Basketball Shoes High Legacy 312 Trainer 3 Medicine Ball Mens Womens Zoom Air White Midnight Navy Ginger Light Bone Sports Sneakers Aq4160-140 ',
#   'link': 'https://www.dhgate.com/product/2023-basketball-shoes-high-legacy-312-trainer/871274408.html',
#   'source': 'DHgate',
#   'source_icon': 'https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn:ANd9GcTRk_908BbD9c9fi9c_9pP_-fj6oLferlbITHSb41latljvczBCfGq9uDORKS-89HUgLGcxXngycdw2tZlHLiiuUSPcx9t630aVm1YjIyg1TNurCA',
#   'price': {'value': '$17.96*', 'extracted_value': 17.96, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTlyDlc2XnS6hWQ4mKxqrkapzPmgF6pbw8OAjXQgZ5xXASo7Q_W',
#   'in_stock': True},
#  {'position': 51,
#   'title': 'Designer flat sniper trainers Casual shoes letter fashion platform men women low trainers Sneakers 36-45 Running Shoes Comfortable anti slip sole ',
#   'link': 'https://www.dhgate.com/product/designer-flat-sniper-trainers-casual-shoes/911479843.html',
#   'source': 'DHgate',
#   'source_icon': 'https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn:ANd9GcTRk_908BbD9c9fi9c_9pP_-fj6oLferlbITHSb41latljvczBCfGq9uDORKS-89HUgLGcxXngycdw2tZlHLiiuUSPcx9t630aVm1YjIyg1TNurCA',
#   'price': {'value': '$72.62*', 'extracted_value': 72.62, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTgXFH-VEAFHm3U95sCTGzxWX6AKIJud8Y0ba9RPvek4PJrgOc2',
#   'in_stock': True},
#  {'position': 52,
#   'title': '2023 Platform Out Of Office Sneaker Designer Casual Shoes Low Tops Pink Light Grey Grey White luxury Plate-forme sports sneakers trainers 35-45',
#   'link': 'https://www.dhgate.com/product/2023-platform-out-of-office-sneaker-designer/888974495.html',
#   'source': 'DHgate',
#   'source_icon': 'https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn:ANd9GcTRk_908BbD9c9fi9c_9pP_-fj6oLferlbITHSb41latljvczBCfGq9uDORKS-89HUgLGcxXngycdw2tZlHLiiuUSPcx9t630aVm1YjIyg1TNurCA',
#   'price': {'value': '$35.04*', 'extracted_value': 35.04, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTZw2JOye9a9RLQ4Nj5_21ECpaPaNDgRqC03k8MoKRQTqSfFFb3',
#   'in_stock': True},
#  {'position': 53,
#   'title': 'Luxury Designer Out Of Office Sneakers - Unisex Casual Leather Shoes in Light Blue, Purple & Yellow',
#   'link': 'https://www.dhgate.com/product/off-og-sneakers-out-of-office-designer-casual/922214462.html',
#   'source': 'DHgate',
#   'source_icon': 'https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn:ANd9GcTRk_908BbD9c9fi9c_9pP_-fj6oLferlbITHSb41latljvczBCfGq9uDORKS-89HUgLGcxXngycdw2tZlHLiiuUSPcx9t630aVm1YjIyg1TNurCA',
#   'price': {'value': '$37.54*', 'extracted_value': 37.54, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTb2vWrKgxJgMPh5QzU5Svj3OeNQScy2DWrHC7qMiyOqcep1Uln',
#   'in_stock': True},
#  {'position': 54,
#   'title': 'Casual Out Of Office Low Top Offs Sneakers Designer White Shoes OOO Women Men Outdoor Sports Lows Panda Pink Green Arrows Motif Platform Vintage Flat ',
#   'link': 'https://www.dhgate.com/product/casual-out-of-office-low-top-offs-sneakers/920892734.html',
#   'source': 'DHgate',
#   'source_icon': 'https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn:ANd9GcTRk_908BbD9c9fi9c_9pP_-fj6oLferlbITHSb41latljvczBCfGq9uDORKS-89HUgLGcxXngycdw2tZlHLiiuUSPcx9t630aVm1YjIyg1TNurCA',
#   'price': {'value': '$34.92*', 'extracted_value': 34.92, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRfqzFi_-Fy7IbDVgS5HMbUqt7YB-W-13NlAoP_vSdB89cwQOuF',
#   'in_stock': True},
#  {'position': 55,
#   'title': 'designer customization size with box dust bag dress shoes luxury high heels women office career vintage wedding black pointed peep toes pumps spikes',
#   'link': 'https://www.dhgate.com/product/new-arrival-running-shoes-pharrell-williams-jyc-1/475302022.html',
#   'source': 'DHgate',
#   'source_icon': 'https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn:ANd9GcTRk_908BbD9c9fi9c_9pP_-fj6oLferlbITHSb41latljvczBCfGq9uDORKS-89HUgLGcxXngycdw2tZlHLiiuUSPcx9t630aVm1YjIyg1TNurCA',
#   'price': {'value': '$17.34*', 'extracted_value': 17.34, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS0qWpN5LIYcweD4Ko7kv95IaIswn5AKmkIrcuBFYd0H36sZaOd',
#   'in_stock': True},
#  {'position': 56,
#   'title': 'Nike Air Jordan Legacy 312 Fly Youth GS 7Y Womens 8.5 CI4446-400 Blue Lagoon',
#   'link': 'https://www.ebay.com/itm/174948098290',
#   'source': 'eBay',
#   'source_icon': 'https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn:ANd9GcT5NXsW5qpQoNKtvnEC0sNL88H54opWmBBYIh2gQ3U_SGUU-yc8xV_BfeECVq4HYfwroQsx3k4lpMvjDByZM4KvONyK63j7aI6RPQrDFwRa9lo',
#   'price': {'value': '$189.00*', 'extracted_value': 189.0, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTayfRH4p897C5BL3edaIAtmp0KSnXnXBlwK1_7ynODpDIV86UV',
#   'condition': 'Used'},
#  {'position': 57,
#   'title': "Size 8 - Nike Dunk Low Sb X Ben & Jerry's Chunky Dunky",
#   'link': 'https://www.ebay.com/itm/204626006236',
#   'source': 'eBay',
#   'source_icon': 'https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn:ANd9GcT5NXsW5qpQoNKtvnEC0sNL88H54opWmBBYIh2gQ3U_SGUU-yc8xV_BfeECVq4HYfwroQsx3k4lpMvjDByZM4KvONyK63j7aI6RPQrDFwRa9lo',
#   'rating': 3.5,
#   'reviews': 8,
#   'price': {'value': '$1,200.00*', 'extracted_value': 1200.0, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSy6WGIwszimXM8hhcx9jpdPgZuJq_CyNkd-mkCCSTPgabU28l-',
#   'condition': 'Used'},
#  {'position': 58,
#   'title': 'Girls Sports Shoes 2021 Autumn Boys Middle Small Children High-top Basketball Running Sneakers Kids Soft-soled Baby Casual Shoes G1025',
#   'link': 'https://www.dhgate.com/product/girls-sports-shoes-2021-autumn-boys-middle/735196389.html',
#   'source': 'DHgate',
#   'source_icon': 'https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn:ANd9GcTRk_908BbD9c9fi9c_9pP_-fj6oLferlbITHSb41latljvczBCfGq9uDORKS-89HUgLGcxXngycdw2tZlHLiiuUSPcx9t630aVm1YjIyg1TNurCA',
#   'price': {'value': '$16.87*', 'extracted_value': 16.87, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSYZKf91mvPN2tEakyX9wYxGPLfxh0Ef7p2ibD0EjWn7nJm41kN',
#   'in_stock': True},
#  {'position': 59,
#   'title': 'A Bathing Ape ︎ Bape Sta 88 1 Blue Gray 2colors Size Us Mens 7-14',
#   'link': 'https://www.ebay.com/itm/315124170892',
#   'source': 'eBay',
#   'source_icon': 'https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn:ANd9GcT5NXsW5qpQoNKtvnEC0sNL88H54opWmBBYIh2gQ3U_SGUU-yc8xV_BfeECVq4HYfwroQsx3k4lpMvjDByZM4KvONyK63j7aI6RPQrDFwRa9lo',
#   'price': {'value': '$282.47*', 'extracted_value': 282.47, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-HH1reX2aCYfl00F2Xj51oZXBJCAdJPhusxtK7PLsw2lK0nke',
#   'in_stock': True},
#  {'position': 60,
#   'title': 'Durable Trainers for Toddler Girls, Preschool Athletic Sneakers',
#   'link': 'https://www.dhgate.com/product/kid-shoes-flat-jogging-walking-platform-shoe/899912245.html',
#   'source': 'DHgate',
#   'source_icon': 'https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn:ANd9GcTRk_908BbD9c9fi9c_9pP_-fj6oLferlbITHSb41latljvczBCfGq9uDORKS-89HUgLGcxXngycdw2tZlHLiiuUSPcx9t630aVm1YjIyg1TNurCA',
#   'price': {'value': '$24.02*', 'extracted_value': 24.02, 'currency': '$'},
#   'thumbnail': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRGQO3o5iDK9UObD4BrOECVT4ROH5cVUeeCRUYRGsMRrOEGcioV',
#   'in_stock': True}]

# %%
import gradio as gr

# Code for Task 1
# hmm = ""

def task1(input_text):
  global hmm
  # Task 1 logic
  hmm = input_text
  return "Task 1 Result: " + input_text

# Code for Task 2
def task2(input):
  # Task 2 logic
  return hmm

# interface one
iface1 = gr.Interface(
  fn=task1,
  inputs="text",
  outputs="text",
  title="Multi-Page Interface"
)
# interface two
iface2 = gr.Interface(
  fn=task2,
  inputs="text",
  outputs="text",
  title="Multi-Page Interface"
)

demo = gr.TabbedInterface([iface1, iface2], ["Text-to-text", "image-to-text"])

# Run the interface
demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7870
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7870/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from serpapi import GoogleSearch
import torch
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration
import gradio as gr
import requests
import io
import base64
from base64 import encodebytes

API_KEY = "9023d4dbcce2c3e065d7983a642218de01ad8c1cc6a9f556d6dd6bd7351943af"

processor = BlipProcessor.from_pretrained(
    "salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained(
    "salesforce/blip-image-captioning-base")


def get_response_image(image):
    """
    Converts a NumPy array image to a base64 encoded string.

    Parameters:
    image (numpy.ndarray): The input image as a NumPy array.

    Returns:
    str: The base64 encoded string representation of the image.
    """
    pil_image = Image.fromarray(image)
    byte_arr = io.BytesIO()
    pil_image.save(byte_arr, format='JPEG')
    encoded_img = encodebytes(byte_arr.getvalue()).decode('ascii')
    return encoded_img


def image_captioning(image):
    """
    Generates a caption for the given image using an API.

    Args:
        image: The input image for which the caption needs to be generated.

    Returns:
        If the API call is successful, returns a PIL image object with the generated caption.
        If the API call fails, returns an error message.

    Raises:
        None
    """
    api_url = "http://127.0.0.1:5000/process_image"
    encoded_input = get_response_image(image)

    files = {"image": encoded_input}
    response = requests.post(api_url, json=files)
    response_json = response.json()
    encoded_image = response_json['ImageBytes']

    if response.status_code == 200:
        decoded_image = base64.b64decode(encoded_image)
        pil_image = Image.open(io.BytesIO(decoded_image))
        return pil_image
    else:
        return "Error: Unable to generate caption"


def generate_caption(image):
    """
    Generates a caption for the given image using image captioning model.

    Args:
        image: The input image for which the caption needs to be generated.

    Returns:
        The generated caption for the image.
    """
    global caption
    segmented_image = image_captioning(image)
    inputs = processor(images=segmented_image, text="", return_tensors="pt")
    with torch.no_grad():
        outputs = model.generate(**inputs)
    caption = processor.decode(outputs[0], skip_special_tokens=True)
    return caption


iface1 = gr.Interface(
    generate_caption,
    gr.Image(),
    "text",
    title="Image Captioning",
    description="Generate a caption for an image.",
)


def display_products(input_text):
    """
    Display products based on the given search parameters.

    Returns:
        str: A string containing HTML markup for displaying the products.
    """
    params = {
        "engine": "google_shopping",
        "q": caption,
        "location": "Bengaluru, Karnataka, India",
        "google_domain": "google.com",
        "gl": "in",
        "hl": "en",
        "api_key": API_KEY,
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    shopping_results = results["shopping_results"]
    shopping_results = shopping_results[:min(15, len(shopping_results))]

    ListOfThumbnails = [items.get('thumbnail') for items in shopping_results]
    ListOfTitles = [items.get('title') for items in shopping_results]
    ListOfPrices = [items.get('price') for items in shopping_results]
    ListOfLinks = [items.get('link') for items in shopping_results]
    ListOfStores = [items.get('source') for items in shopping_results]

    product_display = ""
    for i in range(len(ListOfThumbnails)):
        product_display += f"<img src='{ListOfThumbnails[i]}' width=200><br>"
        product_display += f"<b>Title:</b> {ListOfTitles[i]}<br>"
        product_display += f"<b>Price:</b> {ListOfPrices[i]}<br>"
        product_display += f"<b>Store:</b> {ListOfStores[i]}<br>"
        product_display += f"<a href='{ListOfLinks[i]}' target='_blank'>Link</a><br><br>"

    return product_display


iface2 = gr.Interface(
    fn=display_products,
    inputs=gr.Textbox(lines=2, label="Caption"),
    outputs="html",
    title="Google Shopping Search",
    description="Enter the product you want to search for",
    allow_flagging=False,
    theme="huggingface",
)

demo = gr.TabbedInterface(
  [
    iface1,
    iface2
  ],
  [
    "Image Captioning",
    "Google Shopping Search"
  ]
)

demo.launch()
# Out:
# /home/alpha/.local/lib/python3.10/site-packages/gradio/blocks.py:736: UserWarning: Cannot load huggingface. Caught Exception: 404 Client Error: Not Found for url: https://huggingface.co/api/spaces/huggingface (Request ID: Root=1-66356149-6343d86a3191447b142a28ff;d43d4e74-187d-4a1d-8cd6-8b23c779d606)
#
# Sorry, we can't find the page you are looking for.
#   warnings.warn(f"Cannot load {theme}. Caught Exception: {str(e)}")
# /home/alpha/.local/lib/python3.10/site-packages/gradio/interface.py:377: UserWarning: The `allow_flagging` parameter in `Interface` nowtakes a string value ('auto', 'manual', or 'never'), not a boolean. Setting parameter to: 'never'.
#   warnings.warn(
# Running on local URL:  http://127.0.0.1:7872
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7872/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
